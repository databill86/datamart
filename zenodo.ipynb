# %%
import requests

# %%
r = requests.get('https://zenodo.org/api/records/?page=1&size=20&q=&access_right=open&file_type=csv')
r.raise_for_status()
obj = r.json()

# %%
obj['links']
# Out:
# {'next': 'https://zenodo.org/api/records/?sort=mostrecent&q=&file_type=csv&size=20&access_right=open&page=2',
#  'self': 'https://zenodo.org/api/records/?sort=mostrecent&q=&file_type=csv&size=20&access_right=open&page=1'}

# %%
obj['hits']
# Out:
# {'hits': [{'conceptdoi': '10.5281/zenodo.2441114',
#    'conceptrecid': '2441114',
#    'created': '2018-12-20T04:52:45.718929+00:00',
#    'doi': '10.5281/zenodo.2441115',
#    'files': [{'bucket': '054275bb-b87b-4d48-8de7-8e91eb3899d9',
#      'checksum': 'md5:f2266713a7bc2f92937ae5b085ab5037',
#      'key': 'crude_death_rate_2017_CIA.txt',
#      'links': {'self': 'https://zenodo.org/api/files/054275bb-b87b-4d48-8de7-8e91eb3899d9/crude_death_rate_2017_CIA.txt'},
#      'size': 24860,
#      'type': 'txt'},
#     {'bucket': '054275bb-b87b-4d48-8de7-8e91eb3899d9',
#      'checksum': 'md5:8a7f05d40c11b1e8932f227b725c8f9e',
#      'key': 'crude_death_rate.xls',
#      'links': {'self': 'https://zenodo.org/api/files/054275bb-b87b-4d48-8de7-8e91eb3899d9/crude_death_rate.xls'},
#      'size': 293888,
#      'type': 'xls'},
#     {'bucket': '054275bb-b87b-4d48-8de7-8e91eb3899d9',
#      'checksum': 'md5:76feba79e523e680f2d23c3785a4118e',
#      'key': 'GDP_per_capita.xls',
# ...
